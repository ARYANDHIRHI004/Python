# %%
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset("titanic")

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df[df.dtypes[df.dtypes =="object"].index].describe()
# Out:
#          sex embarked  who  embark_town alive
# count    891      889  891          889   891
# unique     2        3    3            3     2
# top     male        S  man  Southampton    no
# freq     577      644  537          644   549

# %%
df[df['age']< 18]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 7           0       3    male   2.0      3      1  21.0750        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# 10          1       3  female   4.0      1      1  16.7000        S   Third
# 14          0       3  female  14.0      0      0   7.8542        S   Third
# 16          0       3    male   2.0      4      1  29.1250        Q   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 850         0       3    male   4.0      4      2  31.2750        S   Third
# 852         0       3  female   9.0      1      1  15.2458        C   Third
# 853         1       1  female  16.0      0      1  39.4000        S   First
# 869         1       3    male   4.0      1      1  11.1333        S   Third
# 875         1       3  female  15.0      0      0   7.2250        C   Third
#
#        who  adult_male deck  embark_town alive  alone
# 7    child       False  NaN  Southampton    no  False
# 9    child       False  NaN    Cherbourg   yes  False
# 10   child       False    G  Southampton   yes  False
# 14   child       False  NaN  Southampton    no   True
# 16   child       False  NaN   Queenstown    no  False
# ..     ...         ...  ...          ...   ...    ...
# 850  child       False  NaN  Southampton    no  False
# 852  child       False  NaN    Cherbourg    no  False
# 853  woman       False    D  Southampton   yes  False
# 869  child       False  NaN  Southampton   yes  False
# 875  child       False  NaN    Cherbourg   yes   True
#
# [113 rows x 15 columns]

# %%
df[['age']][4:11:2]
# Out:
#      age
# 4   35.0
# 6   54.0
# 8   27.0
# 10   4.0

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
df['new_col'] = df['embarked'] + df['embark_town']

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone       new_col
# 0      man        True  NaN  Southampton    no  False  SSouthampton
# 1    woman       False    C    Cherbourg   yes  False    CCherbourg
# 2    woman       False  NaN  Southampton   yes   True  SSouthampton
# 3    woman       False    C  Southampton   yes  False  SSouthampton
# 4      man        True  NaN  Southampton    no   True  SSouthampton
# ..     ...         ...  ...          ...   ...    ...           ...
# 886    man        True  NaN  Southampton    no   True  SSouthampton
# 887  woman       False    B  Southampton   yes   True  SSouthampton
# 888  woman       False  NaN  Southampton    no  False  SSouthampton
# 889    man        True    C    Cherbourg   yes   True    CCherbourg
# 890    man        True  NaN   Queenstown    no   True   QQueenstown
#
# [891 rows x 16 columns]

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone       new_col
# 0    man        True  NaN  Southampton    no  False  SSouthampton
# 1  woman       False    C    Cherbourg   yes  False    CCherbourg
# 2  woman       False  NaN  Southampton   yes   True  SSouthampton
# 3  woman       False    C  Southampton   yes  False  SSouthampton
# 4    man        True  NaN  Southampton    no   True  SSouthampton

# %%
pd.Categorical(df['pclass'])
# Out:
# [3, 1, 3, 1, 3, ..., 2, 1, 3, 1, 3]
# Length: 891
# Categories (3, int64): [1, 2, 3]

# %%
df['pclass'].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
df[df['age'] < 18]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 7           0       3    male   2.0      3      1  21.0750        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# 10          1       3  female   4.0      1      1  16.7000        S   Third
# 14          0       3  female  14.0      0      0   7.8542        S   Third
# 16          0       3    male   2.0      4      1  29.1250        Q   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 850         0       3    male   4.0      4      2  31.2750        S   Third
# 852         0       3  female   9.0      1      1  15.2458        C   Third
# 853         1       1  female  16.0      0      1  39.4000        S   First
# 869         1       3    male   4.0      1      1  11.1333        S   Third
# 875         1       3  female  15.0      0      0   7.2250        C   Third
#
#        who  adult_male deck  embark_town alive  alone       new_col
# 7    child       False  NaN  Southampton    no  False  SSouthampton
# 9    child       False  NaN    Cherbourg   yes  False    CCherbourg
# 10   child       False    G  Southampton   yes  False  SSouthampton
# 14   child       False  NaN  Southampton    no   True  SSouthampton
# 16   child       False  NaN   Queenstown    no  False   QQueenstown
# ..     ...         ...  ...          ...   ...    ...           ...
# 850  child       False  NaN  Southampton    no  False  SSouthampton
# 852  child       False  NaN    Cherbourg    no  False    CCherbourg
# 853  woman       False    D  Southampton   yes  False  SSouthampton
# 869  child       False  NaN  Southampton   yes  False  SSouthampton
# 875  child       False  NaN    Cherbourg   yes   True    CCherbourg
#
# [113 rows x 16 columns]

# %%
df[df['fare'] > df['fare'].mean()]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 1           1       1  female  38.0      1      0   71.2833        C  First
# 3           1       1  female  35.0      1      0   53.1000        S  First
# 6           0       1    male  54.0      0      0   51.8625        S  First
# 23          1       1    male  28.0      0      0   35.5000        S  First
# 27          0       1    male  19.0      3      2  263.0000        S  First
# ..        ...     ...     ...   ...    ...    ...       ...      ...    ...
# 856         1       1  female  45.0      1      1  164.8667        S  First
# 863         0       3  female   NaN      8      2   69.5500        S  Third
# 867         0       1    male  31.0      0      0   50.4958        S  First
# 871         1       1  female  47.0      1      1   52.5542        S  First
# 879         1       1  female  56.0      0      1   83.1583        C  First
#
#        who  adult_male deck  embark_town alive  alone       new_col
# 1    woman       False    C    Cherbourg   yes  False    CCherbourg
# 3    woman       False    C  Southampton   yes  False  SSouthampton
# 6      man        True    E  Southampton    no   True  SSouthampton
# 23     man        True    A  Southampton   yes   True  SSouthampton
# 27     man        True    C  Southampton    no  False  SSouthampton
# ..     ...         ...  ...          ...   ...    ...           ...
# 856  woman       False  NaN  Southampton   yes  False  SSouthampton
# 863  woman       False  NaN  Southampton    no  False  SSouthampton
# 867    man        True    A  Southampton    no   True  SSouthampton
# 871  woman       False    D  Southampton   yes  False  SSouthampton
# 879  woman       False    C    Cherbourg   yes  False    CCherbourg
#
# [211 rows x 16 columns]

# %%
df[df['fare'] > df['fare'].mean()][['who']]
# Out:
#        who
# 1    woman
# 3    woman
# 6      man
# 23     man
# 27     man
# ..     ...
# 856  woman
# 863  woman
# 867    man
# 871  woman
# 879  woman
#
# [211 rows x 1 columns]

# %%
df["sex"] == "female"
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 886    False
# 887     True
# 888     True
# 889    False
# 890    False
# Name: sex, Length: 891, dtype: bool

# %%
df['fare'] == 32
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: fare, Length: 891, dtype: bool

# %%
df[(df["sex"] == "female") &  (df['fare'] > df.fare.mean())]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 1           1       1  female  38.0      1      0   71.2833        C   First
# 3           1       1  female  35.0      1      0   53.1000        S   First
# 31          1       1  female   NaN      1      0  146.5208        C   First
# 43          1       2  female   3.0      1      2   41.5792        C  Second
# 52          1       1  female  49.0      1      0   76.7292        C   First
# ..        ...     ...     ...   ...    ...    ...       ...      ...     ...
# 853         1       1  female  16.0      0      1   39.4000        S   First
# 856         1       1  female  45.0      1      1  164.8667        S   First
# 863         0       3  female   NaN      8      2   69.5500        S   Third
# 871         1       1  female  47.0      1      1   52.5542        S   First
# 879         1       1  female  56.0      0      1   83.1583        C   First
#
#        who  adult_male deck  embark_town alive  alone       new_col
# 1    woman       False    C    Cherbourg   yes  False    CCherbourg
# 3    woman       False    C  Southampton   yes  False  SSouthampton
# 31   woman       False    B    Cherbourg   yes  False    CCherbourg
# 43   child       False  NaN    Cherbourg   yes  False    CCherbourg
# 52   woman       False    D    Cherbourg   yes  False    CCherbourg
# ..     ...         ...  ...          ...   ...    ...           ...
# 853  woman       False    D  Southampton   yes  False  SSouthampton
# 856  woman       False  NaN  Southampton   yes  False  SSouthampton
# 863  woman       False  NaN  Southampton    no  False  SSouthampton
# 871  woman       False    D  Southampton   yes  False  SSouthampton
# 879  woman       False    C    Cherbourg   yes  False    CCherbourg
#
# [104 rows x 16 columns]

# %%
# Out:
# 512.3292

# %%
df[df.fare ==max(df.fare)][["who"]]
# Out:
#        who
# 258  woman
# 679    man
# 737    man

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone       new_col
# 0      man        True  NaN  Southampton    no  False  SSouthampton
# 1    woman       False    C    Cherbourg   yes  False    CCherbourg
# 2    woman       False  NaN  Southampton   yes   True  SSouthampton
# 3    woman       False    C  Southampton   yes  False  SSouthampton
# 4      man        True  NaN  Southampton    no   True  SSouthampton
# ..     ...         ...  ...          ...   ...    ...           ...
# 886    man        True  NaN  Southampton    no   True  SSouthampton
# 887  woman       False    B  Southampton   yes   True  SSouthampton
# 888  woman       False  NaN  Southampton    no  False  SSouthampton
# 889    man        True    C    Cherbourg   yes   True    CCherbourg
# 890    man        True  NaN   Queenstown    no   True   QQueenstown
#
# [891 rows x 16 columns]

# %%
df[["survived","pclass","sex"]][0:5]
# Out:
#    survived  pclass     sex
# 0         0       3    male
# 1         1       1  female
# 2         1       3  female
# 3         1       1  female
# 4         0       3    male

# %%
df.loc[0:5, ["survived","pclass","sex"]]
# Out:
#    survived  pclass     sex
# 0         0       3    male
# 1         1       1  female
# 2         1       3  female
# 3         1       1  female
# 4         0       3    male
# 5         0       3    male

# %%
df.iloc[0:5, 0:3]
# Out:
#    survived  pclass     sex
# 0         0       3    male
# 1         1       1  female
# 2         1       3  female
# 3         1       1  female
# 4         0       3    male
